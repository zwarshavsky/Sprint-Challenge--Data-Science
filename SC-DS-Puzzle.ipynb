# %%
import sys
import pandas as pd

# %%
df = pd.read_csv("./data/puzzle.csv",header=None)

# %%
df.head(10)
# Out:
#           0         1
# 0  0.397150  2.113629
# 1  0.397150  2.113629
# 2  0.397150  2.113629
# 3  0.397150  2.113629
# 4  0.397150  2.113629
# 5  0.397150  2.113629
# 6  0.397150  2.113629
# 7  0.397150  2.113629
# 8  0.967562 -0.099246
# 9  0.061841 -1.333110

# %%
df[0]
# Out:
# 0       0.397150
# 1       0.397150
# 2       0.397150
# 3       0.397150
# 4       0.397150
#           ...
# 1019    0.658949
# 1020    0.843992
# 1021    0.751561
# 1022    0.906819
# 1023    1.060808
# Name: 0, Length: 1024, dtype: float64

# %%
df[1]
# Out:
# 0       2.113629
# 1       2.113629
# 2       2.113629
# 3       2.113629
# 4       2.113629
#           ...
# 1019   -1.553537
# 1020    0.612621
# 1021    1.299879
# 1022    0.077444
# 1023   -2.824606
# Name: 1, Length: 1024, dtype: float64

# %% [markdown]
# # It's a World Map!

# %%
df.plot.scatter(1,0)

# %%
df[1].value_counts()
# Out:
#  2.113629    101
# -0.151519      2
# -0.672521      2
#  0.408607      2
#  0.047801      2
#             ...
# -1.426130      1
# -1.739777      1
# -1.529086      1
#  0.294713      1
# -1.394802      1
# Name: 1, Length: 912, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df[1],df[0],c=df[0],cmap='brg')
